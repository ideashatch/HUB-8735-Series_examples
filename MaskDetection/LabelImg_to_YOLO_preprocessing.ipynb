# %%
# %cd ..
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# /
# Mounted at /content/gdrive

# %%
# %cd /content/gdrive/MyDrive/maskdetection/
# %ls
# Out:
# /content/gdrive/MyDrive/maskdetection
# classes.txt  my_ai.data          README.dataset.txt   test/
# images/      my_ai.names         README.roboflow.txt  train/
# labels/      my_yolov4-tiny.cfg  results/

# %%
import os
import random

trainval_percent = 0.1
train_percent = 0.9
txtfilepath = 'labels'
imgfilepath = './images/'
total_txt = os.listdir(txtfilepath)

num = len(total_txt)
list = range(num)
tv = int(num * trainval_percent)
tr = int(tv * train_percent)
trainval = random.sample(list, tv)
train = random.sample(trainval, tr)

ftrainval = open('trainval.txt', 'w')
ftest = open('test.txt', 'w')
ftrain = open('train.txt', 'w')
fval = open('val.txt', 'w')

for i in list:
    name = imgfilepath + total_txt[i][:-4] + '.jpg\n'
    if i in trainval:
        ftrainval.write(name)
        if i in train:
            ftest.write(name)
        else:
            fval.write(name)
    else:
        ftrain.write(name)


ftrainval.close()
ftrain.close()
fval.close()
ftest.close()

# %%
cat train.txt val.txt  > all_train.txt

# %%
# %cd /content/gdrive/MyDrive/data
# %ls
# Out:
# /content/gdrive/MyDrive/data
# 13000+/        JPEGimages/  my_ai.names         test.txt      val.txt
# all_train.txt  labels/      my_yolov4-tiny.cfg  train.txt
# images/        my_ai.data   results/            trainval.txt
